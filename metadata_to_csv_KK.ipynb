# %%
from bs4 import BeautifulSoup
import json
import re
from datetime import datetime

import csv
import os

# %%
def get_metadata(the_file):
    
    # Read the file, load it into BS, then grab section we want
    text = the_file.read()
    soup = BeautifulSoup(text, "html5lib")
    my_list = [i.string.lstrip('q("talkPage.init", {\n\t"el": "[data-talk-page]",\n\t "__INITIAL_DATA__":')
               .rstrip('})')
               for i in soup.select('script') 
               if i.string and i.string.startswith('q')]
    
    # Read first layer of JSON and get out those elements we want
    pre_json = '{"' + "".join(my_list)
    my_json = json.loads(pre_json)
    slug = my_json['slug']
    vcount = my_json['viewed_count']
    event = my_json['event']
    
    # Read second layer of JSON and get out listed elements:
    properties = "filmed,published" # No spaces between terms!
    talks_listed = str(my_json['talks']).split(",")
    regex_list = [".*("+i+").*" for i in properties.split(",")]
    matches = []
    for e in regex_list:
        filtered = filter(re.compile(e).match, talks_listed)
        indexed = "".join(filtered).split(":")[1]
        matches.append(indexed)
        print(matches)
    filmed = datetime.utcfromtimestamp(float(matches[0])).strftime('%Y-%m-%d')
#    published = datetime.utcfromtimestamp(float(matches[1])).strftime('%Y-%m-%d')
    return slug, vcount, event, filmed, #published

def to_csv(dir_path, output_csv):
    # OPEN file to which to write:
    with open(output_csv, "w") as out:
        # create csv.writer.
        wr = csv.writer(out)
        # write our headers.
        wr.writerow(["slug", "view_count", "event", "filmed"]) # , "published"
        # get all our html files.
        for html in os.listdir(dir_path):
            with open(os.path.join(dir_path, html),"r", errors="ignore") as f:
                # parse the file and write the data to a row.
                wr.writerow(get_metadata(f))

# %%
to_csv("./html","metadata-2.csv")
# Out:
# [' 1340323200']
# [' 1340323200', ' 1353427357']
# [' 1466812800']
# [' 1466812800', " True 'published'"]
# [' 1340668800']
# [' 1340668800', " True 'published'"]
# [' 1487116800']
# [' 1487116800', " True 'published'"]
# [' 1310601600']
# [' 1310601600', ' 1316618681']
# [' 1305763200']
# [' 1305763200', ' 1322406035']
# [' 1140739200']
# [' 1140739200', ' 1155600660']
# [' 1201910400']
# [' 1201910400', ' 1208839080']
# [' 1365638400']
# [' 1365638400', ' 1380727278']
# [' 1492992000']
# [' 1492992000', " True 'published'"]
# [' 1172880000']
# [' 1172880000', ' 1181044860']
# [' 1467158400']
# [' 1467158400', ' 1471532545&nbsp;about a Muslim immigrant&rsquo;s campaign to spare from Death Row the white supremacist who tried to kill him. In 2011 he published&nbsp;<a href="http']
# [' 1425945600']
# [' 1425945600', " True 'published'"]
# [' 1426636800']
# [' 1426636800', " 1431357590&rdquo; was published on the November 2014 cover of the magazine. This incredible look at parasites won Varma the World Press Photo&#39;s first prize in the nature category in 2015.&nbsp;</p>'"]
# [' 1257984000']
# [' 1257984000', ' 1276851600']
# [' 1371168000']
# [' 1371168000', " True 'published'"]
# [' 1362009600']
# [' 1362009600', ' 1370444552']
# [' 1413244800']
# [' 1413244800', " True 'published'"]
# [' 1290211200']
# [' 1290211200', ' 1295538060']
# [' 1371081600']
# [' 1371081600', ' 1379602886']
# [' 1248220800']
# [' 1248220800', " True 'published'"]
# [' 1422489600']
# [' 1422489600', " True 'published'"]
# [' 1370908800']
# [' 1370908800', " True 'published'"]
# [' 1342224000']
# [' 1342224000', " True 'published'"]
# [' 1358467200']
# [' 1358467200', ' 1366297213']
# [' 1412553600']
# [' 1412553600', " True 'published'"]
# [' 1395014400']
# [' 1395014400', " True 'published'"]
# [' 1265760000']
# [' 1265760000', ' 1288967040']
# [' 1340755200']
# [' 1340755200', ' 1348067318']
# [' 1395187200']
# [' 1395187200', ' 1410880087']
# [' 1373846400']
# [' 1373846400', ' 1381503543']
# [' 1338768000']
# [' 1338768000', ' 1348413016']
# [' 1362009600']
# [' 1362009600', ' 1370881313']
# [' 1181088000']
# [' 1181088000', " True 'published'"]
# [' 1455494400']
# [' 1455494400', " True 'published'"]
# [' 1382486400']
# [' 1382486400', " True 'published'"]
# [' 1394582400']
# [' 1394582400', ' 1400684635 Twenty-Five Years</em></a>&nbsp;was published in April was a finalist for the 2002 Pulitzer Prize and was included in <em>The Times of London</em>&#39;s list of one hundred best books of the decade. It has been published in twenty-four languages. Solomon is also the author of the novel&nbsp;<a href="http']
# [' 1366761600']
# [' 1366761600', " True 'published'"]
# [' 1330387200']
# [' 1330387200', ' 1331051974']
# [' 1455667200']
# [' 1455667200', " True 'published'"]
# [' 1201910400']
# [' 1201910400', " True 'published'"]
# [' 1353024000']
# [' 1353024000', " True 'published'"]
# [' 1412726400']
# [' 1412726400', " True 'published'"]
# [' 1294963200']
# [' 1294963200', ' 1303916940']
# [' 1365033600']
# [' 1365033600', " True 'published'"]
# [' 1354233600']
# [' 1354233600', " True 'published'"]
# [' 1507075200']
# [' 1507075200', ' 1513285212']
# [' 1455753600']
# [' 1455753600', " True 'published'"]
# [' 1412553600']
# [' 1412553600', " True 'published'"]
# [' 1479513600']
# [' 1479513600', " True 'published'"]
# [' 1492992000']
# [' 1492992000', " True 'published'"]
# [' 1291766400']
# [' 1291766400', ' 1303397460 Santa Cruz. He&#39;s the author of&nbsp;<a href="http']
# [' 1257465600']
# [' 1257465600', ' 1273137600 and its newsletter is now published in eight languages and distributed to 75 countries.</p><p>Gupta also worked with the government of India to establish the National Innovation Foundation']
# [' 1492992000']
# [' 1492992000', " True 'published'"]
# [' 1496707200']
# [' 1496707200', " True 'published'"]
# [' 1447459200']
# [' 1447459200', " True 'published'"]
# [' 1480464000']
# [' 1480464000', " True 'published'"]
# [' 1492992000']
# [' 1492992000', " True 'published'"]
# [' 1197417600']
# [' 1197417600', " True 'published'"]
# [' 1443484800']
# [' 1443484800', " True 'published'"]
# [' 1109289600']
# [' 1109289600', ' 1170979860']
# [' 1492992000']
# [' 1492992000', " True 'published'"]
# [' 1310688000']
# [' 1310688000', ' 1320247325']
# [' 1394841600']
# [' 1394841600', " True 'published'"]
# [' 1492992000']
# [' 1492992000', " True 'published'"]
# [' 1492992000']
# [' 1492992000', " True 'published'"]
# [' 1370908800']
# [' 1370908800', ' 1394637629']
# [' 1383091200']
# [' 1383091200', " True 'published'"]
# [' 1370563200']
# [' 1370563200', ' 1393602268']
# [' 1279152000']
# [' 1279152000', ' 1285146180']
# [' 1310428800']
# [' 1310428800', ' 1322584286']
# [' 1299024000']
# [' 1299024000', " True 'published'"]
# [' 1444435200']
# [' 1444435200', " True 'published'"]
# [' 1256083200']
# [' 1256083200', ' 1264063980']
# [' 1299110400']
# [' 1299110400', " True 'published'"]
# [' 1492992000']
# [' 1492992000', " True 'published'"]
# [' 1455494400']
# [' 1455494400', " True 'published'"]
# [' 1299024000']
# [' 1299024000', ' 1324310558']
# [' 1289174400']
# [' 1289174400', " True 'published'"]
# [' 1449532800']
# [' 1449532800', ' 1450455390']
# [' 1340668800']
# [' 1340668800', ' 1347030007']
# [' 1257465600']
# [' 1257465600', ' 1259802000']
# [' 1426464000']
# [' 1426464000', " True 'published'"]
# [' 1375747200']
# [' 1375747200', ' 1391789702']
# [' 1310601600']
# [' 1310601600', ' 1320766364']
# [' 1370995200']
# [' 1370995200', ' 1379084559']
# [' 1477008000']
# [' 1477008000', " True 'published'"]
# [' 1291680000']
# [' 1291680000', " True 'published'"]
# [' 1316736000']
# [' 1316736000', ' 1296058080']
# [' 1346544000']
# [' 1346544000', ' 1348927347']
# [' 1492992000']
# [' 1492992000', " True 'published'"]
# [' 1107302400']
# [' 1107302400', ' 1197504780']
# [' 1233792000']
# [' 1233792000', ' 1246265400']
# [' 1370995200']
# [' 1370995200', " True 'published'"]
# [' 1455494400']
# [' 1455494400', " True 'published'"]
# [' 1078272000']
# [' 1078272000', ' 1211875620']
# [' 1279152000']
# [' 1279152000', ' 1291391400']
# [' 1337472000']
# [' 1337472000', ' 1352824689']
# [' 1291852800']
# [' 1291852800', " True 'published'"]
# [' 1379030400']
# [' 1379030400', " True 'published'"]
# [' 1411776000']
# [' 1411776000', ' 1436541075']
# [' 1412553600']
# [' 1412553600', ' 1420473578']
# [' 1257465600']
# [' 1257465600', ' 1261555680']
# [' 1477526400']
# [' 1477526400', " True 'published'"]
# [' 1121126400']
# [' 1121126400', ' 1161130260']
# [' 1492992000']
# [' 1492992000', " True 'published'"]
# [' 1480723200']
# [' 1480723200', " True 'published'"]
# [' 1432684800']
# [' 1432684800', ' 1436885955']
# [' 1233792000']
# [' 1233792000', ' 1234980000']
# [' 1455494400']
# [' 1455494400', " True 'published'"]
# [' 1330560000']
# [' 1330560000', " True 'published'"]
# [' 1492992000']
# [' 1492992000', " True 'published'"]
# [' 1121299200']
# [' 1121299200', " True 'published'"]
# [' 1446508800']
# [' 1446508800', ' 1456330901']
# [' 1500508800']
# [' 1500508800', " True 'published'"]
# [' 1449532800']
# [' 1449532800', " True 'published'"]
# [' 1279238400']
# [' 1279238400', ' 1289488560']
# [' 1394668800']
# [' 1394668800', ' 1411053523']
# [' 1319846400']
# [' 1319846400', " 1330188560 </em>published in 2006.</p>'"]
# [' 1323302400']
# [' 1323302400', ' 1326211816']
# [' 1330300800']
# [' 1330300800', " True 'published'"]
# [' 1395187200']
# [' 1395187200', " True 'published'"]
# [' 1395014400']
# [' 1395014400', " True 'published'"]
# [' 1337385600']
# [' 1337385600', ' 1342623575']
# [' 1340582400']
# [' 1340582400', " True 'published'"]
# [' 1334880000']
# [' 1334880000', " True 'published'"]
# [' 1398470400']
# [' 1398470400', " True 'published'"]
# [' 1271376000']
# [' 1271376000', ' 1286355180']
# [' 1410825600']
# [' 1410825600', " True 'published'"]
# [' 1214784000']
# [' 1214784000', ' 1232586900']
# [' 1233964800']
# [' 1233964800', " True 'published'"]
# [' 1121385600']
# [' 1121385600', " True 'published'"]
# [' 1395187200']
# [' 1395187200', " True 'published'"]
# [' 1290038400']
# [' 1290038400', " True 'published'"]
# [' 1333324800']
# [' 1333324800', " True 'published'"]
# [' 1275609600']
# [' 1275609600', " True 'published'"]
# [' 1270598400']
# [' 1270598400', ' 1288169880']
# [' 1412553600']
# [' 1412553600', " True 'published'"]
# [' 1370822400']
# [' 1370822400', ' 1375113177']
# [' 1361836800']
# [' 1361836800', ' 1375455604']
# [' 1298937600']
# [' 1298937600', " True 'published'"]
# [' 1340668800']
# [' 1340668800', ' 1350486799']
# [' 1248307200']
# [' 1248307200', ' 1254992700']
# [' 1340668800']
# [' 1340668800', ' 1343920031']
# [' 1248307200']
# [' 1248307200', ' 1256718540']
# [' 1336608000']
# [' 1336608000', " True 'published'"]
# [' 1412640000']
# [' 1412640000', ' 1428332362']
# [' 1415145600']
# [' 1415145600', " True 'published'"]
# [' 1267142400']
# [' 1267142400', " True 'published'"]
# [' 1172880000']
# [' 1172880000', ' 1201059900']
# [' 1310515200']
# [' 1310515200', ' 1317309649']
# [' 1338854400']
# [' 1338854400', " True 'blurb'"]
# [' 1310601600']
# [' 1310601600', ' 1320857641']
# [' 1014854400']
# [' 1014854400', ' 1240437060']
# [' 1109203200']
# [' 1109203200', " True 'published'"]
# [' 1395273600']
# [' 1395273600', ' 1417534901']
# [' 1352246400']
# [' 1352246400', ' 1355500841']
# [' 1414800000']
# [' 1414800000', ' 1424966283']
# [' 1426550400']
# [' 1426550400', ' 1439218641']
# [' 1371772800']
# [' 1371772800', " True 'published'"]
# [' 1491523200']
# [' 1491523200', " True 'published'"]
# [' 1216425600']
# [' 1216425600', ' 1229475600']
# [' 1201910400']
# [' 1201910400', " True 'published'"]
# [' 1265932800']
# [' 1265932800', ' 1278408000']
# [' 1370995200']
# [' 1370995200', ' 1373900562']
# [' 1248393600']
# [' 1248393600', " True 'published'"]
# [' 1496707200']
# [' 1496707200', " True 'published'"]
# [' 1340755200']
# [' 1340755200', ' 1347722978']
# [' 1467158400']
# [' 1467158400', " True 'published'"]
# [' 1291766400']
# [' 1291766400', ' 1292858280']
# [' 1313539200']
# [' 1313539200', ' 1327157906']
# [' 1395100800']
# [' 1395100800', " True 'published'"]
# [' 1173312000']
# [' 1173312000', " True 'published'"]
# [' 1256428800']
# [' 1256428800', ' 1264411800']
# [' 1319500800']
# [' 1319500800', " True 'published'"]
# [' 1299110400']
# [' 1299110400', ' 1308581400']
# [' 1265932800']
# [' 1265932800', " 1266454800&quot; is published by the <em>New England Journal of Medicine.</em>    </p>'"]
# [' 1299110400']
# [' 1299110400', " 1299270660&quot; is published by the <em>New England Journal of Medicine.</em>    </p>'"]
# [' 1367884800']
# [' 1367884800', " 1368025280&quot; is published by the <em>New England Journal of Medicine.</em>    </p>'"]
# [' 1426636800']
# [' 1426636800', " 1428073125&quot; is published by the <em>New England Journal of Medicine.</em>    </p>'"]
# [' 1233532800']
# [' 1233532800', " 1233800640&quot; is published by the <em>New England Journal of Medicine.</em>    </p>'"]
# [' 1044144000']
# [' 1044144000', ' 1233593580']
# [' 1426723200']
# [' 1426723200', ' 1433171625']
# [' 1138838400']
# [' 1138838400', " True 'published'"]
# [' 1172880000']
# [' 1172880000', ' 1182941400']
# [' 1012608000']
# [' 1012608000', " True 'published'"]
# [' 1426636800']
# [' 1426636800', " True 'published'"]
# [' 1432771200']
# [' 1432771200', ' 1441985216']
# [' 1330387200']
# [' 1330387200', ' 1332517375']
# [' 1395273600']
# [' 1395273600', ' 1403277125']
# [' 886377600']
# [' 886377600', ' 1216170000']
# [' 1282953600']
# [' 1282953600', ' 1291044840']
# [' 1426809600']
# [' 1426809600', " True 'published'"]
# [' 1248307200']
# [' 1248307200', " True 'published'"]
# [' 1304899200']
# [' 1304899200', " True 'published'"]
# [' 1107302400']
# [' 1107302400', " True 'published'"]
# [' 1361923200']
# [' 1361923200', " True 'published'"]
# [' 1265846400']
# [' 1265846400', " True 'published'"]
# [' 1172880000']
# [' 1172880000', " True 'published'"]
# [' 1463529600']
# [' 1463529600', " True 'published'"]
# [' 1341014400']
# [' 1341014400', ' 1341242739']
# [' 1368662400']
# [' 1368662400', " True 'published'"]
# [' 1164931200']
# [' 1164931200', ' 1181125860']
# [' 1348876800']
# [' 1348876800', " True 'published'"]
# [' 1244592000']
# [' 1244592000', ' 1267232400']
# [' 1336176000']
# [' 1336176000', ' 1357833607']
# [' 1413763200']
# [' 1413763200', " True 'published'"]
# [' 1233878400']
# [' 1233878400', ' 1239152400']
# [' 1109203200']
# [' 1109203200', " True 'published'"]
# [' 1361836800']
# [' 1361836800', " True 'published'"]
# [' 1386201600']
# [' 1386201600', ' 1386605235']
# [' 1395100800']
# [' 1395100800', ' 1395758915']
# [' 1320969600']
# [' 1320969600', ' 1335709649']
# [' 886377600']
# [' 886377600', " True 'published'"]
# [' 1330646400']
# [' 1330646400', ' 1331911014']
# [' 1275782400']
# [' 1275782400', " True 'published'"]
# [' 1197417600']
# [' 1197417600', ' "Brewster Kahle is building a truly huge digital library -- every book ever published \'published\'']
# [' 1204502400']
# [' 1204502400', ' 1209433620']
# [' 1233792000']
# [' 1233792000', ' 1241169960']
# [' 1271635200']
# [' 1271635200', ' 1275557100']
# [' 1415059200']
# [' 1415059200', " True 'published'"]
# [' 1320969600']
# [' 1320969600', " True 'published'"]
# [' 1107302400']
# [' 1107302400', ' 1208908200']
# [' 1330300800']
# [' 1330300800', ' 1335194343']
# [' 1455580800']
# [' 1455580800', " True 'published'"]
# [' 1271376000']
# [' 1271376000', " 1275428160 Brian Skerry has had twelve stories published in the magazine with several more upcoming.</p>'"]
# [' 1306108800']
# [' 1306108800', ' 1322237894']
# [' 1477440000']
# [' 1477440000', " True 'published'"]
# [' 1299110400']
# [' 1299110400', " True 'published'"]
# [' 1418256000']
# [' 1418256000', " True 'published'"]
# [' 1233964800']
# [' 1233964800', " True 'published'"]
# [' 1360540800']
# [' 1360540800', " True 'published'"]
# [' 1286668800']
# [' 1286668800', ' 1296149280 and&nbsp;<a href="http']
# [' 1210550400']
# [' 1210550400', ' 1237424400']
# [' 1286668800']
# [' 1286668800', ' 1303826040 and was described by <em>Wired</em> as &quot;the book the National Security Agency wanted never to be published.&quot; His book on computer and network security']
# [' 1201910400']
# [' 1201910400', " True 'published'"]
# [' 1358985600']
# [' 1358985600', " True 'published'"]
# [' 1412553600']
# [' 1412553600', " True 'published'"]
# [' 1330560000']
# [' 1330560000', " True 'published'"]
# [' 1310601600']
# [' 1310601600', ' 1318864131']
# [' 1140739200']
# [' 1140739200', " True 'published'"]
# [' 981676800']
# [' 981676800', ' 1238374800 among other honors. He also published five works of translation and a psychologically introspective memoir']
# [' 1480464000']
# [' 1480464000', " True 'published'"]
# [' 1499472000']
# [' 1499472000', ' 1505142060']
# [' 1340323200']
# [' 1340323200', " True 'published'"]
# [' 1479168000']
# [' 1479168000', " True 'published'"]
# [' 1197417600']
# [' 1197417600', ' 1222304400']
# [' 1449532800']
# [' 1449532800', ' 1457453154']
# [' 1268438400']
# [' 1268438400', ' 1276766340']
# [' 1351296000']
# [' 1351296000', " True 'published'"]
# [' 1140912000']
# [' 1140912000', " True 'published'"]
# [' 1235174400']
# [' 1235174400', " True 'published'"]
# [' 1464739200']
# [' 1464739200', ' 1474988829']
# [' 1299110400']
# [' 1299110400', " True 'published'"]
# [' 1362009600']
# [' 1362009600', " True 'published'"]
# [' 1343001600']
# [' 1343001600', " True 'published'"]
# [' 1233792000']
# [' 1233792000', " True 'published'"]
# [' 1370995200']
# [' 1370995200', " True 'published'"]
# [' 1477094400']
# [' 1477094400', " True 'published'"]
# [' 1120694400']
# [' 1120694400', ' 1172621460']
# [' 1277683200']
# [' 1277683200', ' 1278926880']
# [' 1444435200']
# [' 1444435200', " True 'published'"]
# [' 1330387200']
# [' 1330387200', " True 'published'"]
# [' 1299024000']
# [' 1299024000', ' 1304433480']
# [' 1496707200']
# [' 1496707200', " True 'published'"]
# [' 1107302400']
# [' 1107302400', ' 1221181200']
# [' 1255132800']
# [' 1255132800', " True 'published'"]
# [' 1415664000']
# [' 1415664000', " True 'published'"]
# [' 1447459200']
# [' 1447459200', ' 1458658582']
# [' 1291334400']
# [' 1291334400', ' 1302273180']
# [' 1107302400']
# [' 1107302400', ' 1175835900']
# [' 1477440000']
# [' 1477440000', " True 'published'"]
# [' 1278633600']
# [' 1278633600', ' 1284712140']
# [' 1461456000']
# [' 1461456000', ' 1503604806']
# [' 1233878400']
# [' 1233878400', ' 1242896460']
# [' 1172880000']
# [' 1172880000', ' 1191216180']
# [' 1248220800']
# [' 1248220800', " True 'published'"]
# [' 1455494400']
# [' 1455494400', " True 'published'"]
# [' 1477094400']
# [' 1477094400', " True 'published'"]
# [' 1265846400']
# [' 1265846400', ' 1277975100']
# [' 1248307200']
# [' 1248307200', " True 'published'"]
# [' 1432771200']
# [' 1432771200', ' 1491231086']
# [' 1455840000']
# [' 1455840000', ' 1457722800']
# [' 1254873600']
# [' 1254873600', ' 1261572540']
# [' 1342051200']
# [' 1342051200', ' 1363359960']
# [' 1379635200']
# [' 1379635200', " True 'published'"]
# [' 1413244800']
# [' 1413244800', " True 'published'"]
# [' 1266019200']
# [' 1266019200', ' 1271234700']
# [' 1233878400']
# [' 1233878400', ' 1245286800']
# [' 1492992000']
# [' 1492992000', " True 'published'"]
# [' 1455580800']
# [' 1455580800', " True 'published'"]
# [' 1430438400']
# [' 1430438400', " True 'published'"]
# [' 1340582400']
# [' 1340582400', " True 'published'"]
# [' 1440547200']
# [' 1440547200', ' 1445959451']
# [' 1330646400']
# [' 1330646400', " True 'published'"]
# [' 1290038400']
# [' 1290038400', ' 1302040260']
# [' 1465344000']
# [' 1465344000', " True 'published'"]
# [' 1287964800']
# [' 1287964800', ' 1295368380']
# [' 1479168000']
# [' 1479168000', " True 'published'"]
# [' 1257379200']
# [' 1257379200', ' 1261040760']
# [' 1210118400']
# [' 1210118400', ' 1226477280']
# [' 1109808000']
# [' 1109808000', ' 1263549540']
# [' 1310515200']
# [' 1310515200', ' 1318001156']
# [' 1272153600']
# [' 1272153600', ' 1277282880']
# [' 1121299200']
# [' 1121299200', ' 1170202260']
# [' 1319760000']
# [' 1319760000', " True 'published'"]
# [' 1288915200']
# [' 1288915200', " True 'published'"]
# [' 1371081600']
# [' 1371081600', ' 1382454693']
# [' 1305072000']
# [' 1305072000', " True 'published'"]
# [' 1371168000']
# [' 1371168000', " True 'published'"]
# [' 1395100800']
# [' 1395100800', " True 'published'"]
# [' 1440547200']
# [' 1440547200', " True 'published'"]
# [' 1266710400']
# [' 1266710400', ' 1323273005']
# [' 1429833600']
# [' 1429833600', " 1504276143 'whylisten'"]
# [' 1479513600']
# [' 1479513600', ' 1498143806']
# [' 1444867200']
# [' 1444867200', ' "Explore this list of Chieko\'s published research on assistive technology." \'published\'']
# [' 1503792000']
# [' 1503792000', " True 'published'"]
# [' 1248307200']
# [' 1248307200', ' 1254877200']
# [' 1354320000']
# [' 1354320000', ' 1492181577']
# [' 1477612800']
# [' 1477612800', ' 1482235189']
# [' 1265932800']
# [' 1265932800', ' 1277108940']
# [' 1330560000']
# [' 1330560000', " True 'published'"]
# [' 1431388800']
# [' 1431388800', " True 'published'"]
# [' 1201910400']
# [' 1201910400', ' 1216688400 published when he was 16 Abani published <em><a href="http']
# [' 1181088000']
# [' 1181088000', ' 1186647000 published when he was 16 Abani published <em><a href="http']
# [' 1279152000']
# [' 1279152000', ' 1284450120 it published 150 magazines and websites and employed 2']
# [' 1075680000']
# [' 1075680000', ' 1177632660']
# [' 1012608000']
# [' 1012608000', ' 1201658220 it published 150 magazines and websites and employed 2']
# [' 1458777600']
# [' 1458777600', " True 'published'"]
# [' 1012608000']
# [' 1012608000', ' 1175731860']
# [' 1324339200']
# [' 1324339200', ' 1329843298']
# [' 1426723200']
# [' 1426723200', ' 1432307632']
# [' 1381363200']
# [' 1381363200', ' 1404141526']
# [' 1381449600']
# [' 1381449600', " True 'published'"]
# [' 1337385600']
# [' 1337385600', ' 1342018823']
# [' 1395100800']
# [' 1395100800', " True 'published'"]
# [' 1201910400']
# [' 1201910400', ' 1213563600']
# [' 1394496000']
# [' 1394496000', " True 'published'"]
# [' 1385424000']
# [' 1385424000', ' 1392221219']
# [' 1426636800']
# [' 1426636800', ' 1429714783']
# [' 1455753600']
# [' 1455753600', " True 'published'"]
# [' 1503792000']
# [' 1503792000', " True 'published'"]
# [' 1426464000']
# [' 1426464000', ' 1435331640']
# [' 1477612800']
# [' 1477612800', ' 1510866029']
# [' 1503792000']
# [' 1503792000', " True 'published'"]
# [' 1455667200']
# [' 1455667200', ' 1460991320']
# [' 1505865600']
# [' 1505865600', " True 10 years before it could be published in Vietnam.' 'published'"]
# [' 1278633600']
# [' 1278633600', ' 1284972180']
# [' 1330300800']
# [' 1330300800', ' 1334934782']
# [' 1440720000']
# [' 1440720000', " True 'published'"]
# [' 1298073600']
# [' 1298073600', ' 1317738674']
# [' 1445040000']
# [' 1445040000', " True 'published'"]
# [' 1012608000']
# [' 1012608000', ' 1238634000']
# [' 1204243200']
# [' 1204243200', ' 1206377160']
# [' 1381190400']
# [' 1381190400', ' 1396970042']
# [' 1265932800']
# [' 1265932800', ' 1275467340']
# [' 1278806400']
# [' 1278806400', ' 1296748080']
# [' 1362009600']
# [' 1362009600', " True 'published'"]
# [' 1426550400']
# [' 1426550400', " True 'published'"]
# [' 1376265600']
# [' 1376265600', " True 'published'"]
# [' 1467158400']
# [' 1467158400', " True 'published'"]
# [' 1371859200']
# [' 1371859200', ' 1378393234']
# [' 1289433600']
# [' 1289433600', ' 1301067000']
# [' 1243987200']
# [' 1243987200', " True 'published'"]
# [' 1277164800']
# [' 1277164800', " True 'published'"]
# [' 1340668800']
# [' 1340668800', " True 'published'"]
# [' 1120176000']
# [' 1120176000', " True 'published'"]
# [' 1141084800']
# [' 1141084800', ' 1206493200']
# [' 1425945600']
# [' 1425945600', " True 'published'"]
# [' 1404777600']
# [' 1404777600', " True 'published'"]
# [' 1358467200']
# [' 1358467200', ' 1364482993']
# [' 1351209600']
# [' 1351209600', " True 'published'"]
# [' 1351209600']
# [' 1351209600', ' 1358957905']
# [' 1353110400']
# [' 1353110400', " True 'published'"]
# [' 1278633600']
# [' 1278633600', ' 1289833380']
# [' 1181088000']
# [' 1181088000', ' 1215392400']
# [' 1425945600']
# [' 1425945600', " True 'published'"]
# [' 1291939200']
# [' 1291939200', ' 1299601440']
# [' 1455840000']
# [' 1455840000', " True 'published'"]
# [' 1204156800']
# [' 1204156800', " True 'published'"]
# [' 1109203200']
# [' 1109203200', ' 1175731860']
# [' 1274400000']
# [' 1274400000', ' 1274433180']
# [' 1412121600']
# [' 1412121600', ' 1421424131 Spain. <br /><br />Her published works include &ldquo;Impalpable&rdquo; (1994)']
# [' 1453420800']
# [' 1453420800', ' 1492786821']
# [' 1291766400']
# [' 1291766400', ' 1297180140']
# [' 1492992000']
# [' 1492992000', ' 1509104618']
# [' 1310515200']
# [' 1310515200', ' 1321545834']
# [' 1246924800']
# [' 1246924800', ' 1258074000']
# [' 1492992000']
# [' 1492992000', " True 'published'"]
# [' 1396310400']
# [' 1396310400', ' 1396324857']
# [' 1294531200']
# [' 1294531200', ' 1296575040']
# [' 1334793600']
# [' 1334793600', ' 1338391538']
# [' 1455494400']
# [' 1455494400', " True 'published'"]
# [' 1449532800']
# [' 1449532800', ' 1454947702']
# [' 1371081600']
# [' 1371081600', ' 1384186168']
# [' 1426809600']
# [' 1426809600', ' 1435591142']
# [' 1426636800']
# [' 1426636800', " True 'published'"]
# [' 1330300800']
# [' 1330300800', ' 1339086629']
# [' 1492992000']
# [' 1492992000', " True 'published'"]
# [' 1305331200']
# [' 1305331200', ' 1307371080']
# [' 1299196800']
# [' 1299196800', ' 1322497367']
# [' 1229040000']
# [' 1229040000', " True 'published'"]
# [' 1298937600']
# [' 1298937600', " True 'published'"]
# [' 1426550400']
# [' 1426550400', " True 'published'"]
# [' 1233964800']
# [' 1233964800', " True 'published'"]
# [' 1351036800']
# [' 1351036800', " True 'published'"]
# [' 1404864000']
# [' 1404864000', ' 1410360940']
# [' 1265760000']
# [' 1265760000', ' 1268211600 and was named one of the world&#39;s most influential people in Time&rsquo;s annual &quot;Time 100&quot; list. In 2014 he published <a href="http']
# [' 1216339200']
# [' 1216339200', ' 1227556620 and was named one of the world&#39;s most influential people in Time&rsquo;s annual &quot;Time 100&quot; list. In 2014 he published <a href="http']
# [' 1477008000']
# [' 1477008000', " True 'published'"]
# [' 1383091200']
# [' 1383091200', " True 'published'"]
# [' 1479513600']
# [' 1479513600', " True 'published'"]
# [' 1251849600']
# [' 1251849600', " True 'published'"]
# [' 1279152000']
# [' 1279152000', ' 1282902540']
# [' 1233792000']
# [' 1233792000', ' 1237165200']
# [' 1012608000']
# [' 1012608000', ' 1183412700']
# [' 1046304000']
# [' 1046304000', ' 1175855580']
# [' 1496707200']
# [' 1496707200', " True 'published'"]
# [' 1075680000']
# [' 1075680000', " True 'published'"]
# [' 1120694400']
# [' 1120694400', ' 1229412720</em> published in 2006']
# [' 1395100800']
# [' 1395100800', ' 1401807363</em> published in 2006']
# [' 1455667200']
# [' 1455667200', " True 'published'"]
# [' 1267833600']
# [' 1267833600', " True 'published'"]
# [' 1394841600']
# [' 1394841600', ' 1407941262']
# [' 1455494400']
# [' 1455494400', " True 'published'"]
# [' 1362096000']
# [' 1362096000', " True 'published'"]
# [' 1286841600']
# [' 1286841600', " True 'published'"]
# [' 1248393600']
# [' 1248393600', " True 'published'"]
# [' 1320796800']
# [' 1320796800', ' 1324485231']
# [' 1172880000']
# [' 1172880000', ' 1197938280']
# [' 1361577600']
# [' 1361577600', ' 1375714807']
# [' 1265760000']
# [' 1265760000', ' 1267434300']
# [' 1426550400']
# [' 1426550400', " True 'published'"]
# [' 1233878400']
# [' 1233878400', ' 1247619600 a company developing technologies to enable adult stem cell based regenerative therapies.&nbsp; <br /><br />Daniel is an avid pilot and serves as a officer and flight surgeon with an F-16 Squadron in the California Air National Guard. He has conducted research on aerospace medicine that was published with NASA']
# [' 1301875200']
# [' 1301875200', ' 1307970840 a company developing technologies to enable adult stem cell based regenerative therapies.&nbsp; <br /><br />Daniel is an avid pilot and serves as a officer and flight surgeon with an F-16 Squadron in the California Air National Guard. He has conducted research on aerospace medicine that was published with NASA']
# [' 1443484800']
# [' 1443484800', " True 'published'"]
# [' 1233878400']
# [' 1233878400', ' 1246410000']
# [' 1270857600']
# [' 1270857600', " True 'published'"]
# [' 1361923200']
# [' 1361923200', " True 'published'"]
# [' 1321660800']
# [' 1321660800', ' 1333203214']
# [' 1370908800']
# [' 1370908800', " True 'published'"]
# [' 1299110400']
# [' 1299110400', ' 1308667620']
# [' 1310515200']
# [' 1310515200', ' 1320332130']
# [' 1415577600']
# [' 1415577600', " True 'published'"]
# [' 1310428800']
# [' 1310428800', ' 1317394229']
# [' 1446681600']
# [' 1446681600', ' 1459953778']
# [' 1447459200']
# [' 1447459200', ' 1449592110']
# [' 1460678400']
# [' 1460678400', " True 'published'"]
# [' 761702400']
# [' 761702400', ' 1328285197']
# [' 1361923200']
# [' 1361923200', " True 'published'"]
# [' 1288051200']
# [' 1288051200', ' 1298564220']
# [' 1508198400']
# [' 1508198400', " True 'published'"]
# [' 1340323200']
# [' 1340323200', ' 1353341964']
# [' 1340668800']
# [' 1340668800', " True 'published'"]
# [' 1403568000']
# [' 1403568000', ' 1412348486']
# [' 1442620800']
# [' 1442620800', ' 1471013398']
# [' 1301875200']
# [' 1301875200', ' 1309363260']
# [' 1204156800']
# [' 1204156800', " True 'published'"]
# [' 1426550400']
# [' 1426550400', " True 'published'"]
# [' 1286668800']
# [' 1286668800', ' 1302618600']
# [' 1413158400']
# [' 1413158400', " True 'published'"]
# [' 1255132800']
# [' 1255132800', " True 'published'"]
# [' 1358467200']
# [' 1358467200', ' 1363100515']
# [' 1475107200']
# [' 1475107200', " True 'published'"]
# [' 1499472000']
# [' 1499472000', " True published posthumously 'published'"]
# [" 1340668800 'whylisten'"]
# [" 1340668800 'whylisten'", ' 1353081633']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-a5fc41b96b72> in <module>()
# ----> 1 to_csv("./html","metadata-2.csv")
#
# <ipython-input-4-418cd1de7fb6> in to_csv(dir_path, output_csv)
#      41             with open(os.path.join(dir_path, html),"r", errors="ignore") as f:
#      42                 # parse the file and write the data to a row.
# ---> 43                 wr.writerow(get_metadata(f))
#
# <ipython-input-4-418cd1de7fb6> in get_metadata(the_file)
#      26         matches.append(indexed)
#      27         print(matches)
# ---> 28     filmed = datetime.utcfromtimestamp(float(matches[0])).strftime('%Y-%m-%d')
#      29 #    published = datetime.utcfromtimestamp(float(matches[1])).strftime('%Y-%m-%d')
#      30     return slug, vcount, event, filmed, #published
#
# ValueError: could not convert string to float: " 1340668800 'whylisten'"

# %% [markdown]
# These are alternate ways to open files in Python that may solve various reading errors.

# %%
def to_csv_codecs(dir_path, output_csv):
    # LOAD required modules
    import csv
    import os
    import codecs
    # OPEN file to which to write:
    with open(output_csv, "w") as out:
        # create csv.writer.
        wr = csv.writer(out)
        # write our headers.
        wr.writerow(["slug", "view_count", "event", "filmed", "published"])
        # get all our html files.
        for html in os.listdir(dir_path):
            with codecs.open(os.path.join(dir_path, html),"r", 
                             encoding='utf-8', errors='ignore') as f:
                # parse the file and write the data to a row.
                wr.writerow(get_metadata(f))
                
def to_csv_io(dir_path, output_csv):
    # LOAD required modules
    import csv
    import os
    import io
    # OPEN file to which to write:
    with open(output_csv, "w") as out:
        # create csv.writer.
        wr = csv.writer(out)
        # write our headers.
        wr.writerow(["slug", "view_count", "event", "filmed", "published"])
        # get all our html files.
        for html in os.listdir(dir_path):
            with io.open(os.path.join(dir_path, html),"r") as f:
                # parse the file and write the data to a row.
                wr.writerow(get_metadata(f))
